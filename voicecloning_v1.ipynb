# %% [markdown]
# <a href="https://colab.research.google.com/github/kushalbadal/Real-Time-Voice-Cloning/blob/master/voicecloning_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r /content/drive/MyDrive/Colab\ Notebooks/cloning/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 32.8 MB/s
# ...
#      |████████████████████████████████| 241 kB 48.8 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=f0eab72ea1cbbdc26e80b16da036f7499ecafd4bf0e55efebaa5e599570ebd0d
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=d11691476eff878aa8e57694ac394e3bfc065e3a116d1eb59c28fdd6032c1c12
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...

# %%
# !pip install webrtcvad
# Out:
# ...
#      |████████████████████████████████| 66 kB 4.8 MB/s
# ...
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp37-cp37m-linux_x86_64.whl size=72405 sha256=9e6c16df1fc7b1900617b6ed91baee81699347b69c0dcd50b8cbb500c63ece5a
#   Stored in directory: /root/.cache/pip/wheels/11/f9/67/a3158d131f57e1c0a7d8d966a707d4a2fb27567a4fe47723ad
# Successfully built webrtcvad
# ...

# %%
# !pip install unidecode

# %%
# !python /content/drive/MyDrive/Colab\ Notebooks/cloning/synthesizer_train.py mr_run  /content/drive/MyDrive/Colab\ Notebooks/cloning/datasets/SV2TTS/synthesizer/
# Out:
# Arguments:
#     run_id:          mr_run
#     syn_dir:         /content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/
#     models_dir:      /content/drive/MyDrive/Colab Notebooks/cloning/synthesizer/saved_models/
#     save_every:      1000
#     backup_every:    25000
#     force_restart:   False
#     hparams:
#
# Checkpoint path: /content/drive/MyDrive/Colab Notebooks/cloning/synthesizer/saved_models/mr_run/mr_run.pt
# Loading training data from: /content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/train.txt
# Using model: Tacotron
# Using device: cuda
#
# Initialising Tacotron Model...
#
# Trainable Parameters: 30.870M
#
# Starting the training of Tacotron from scratch
#
# Using inputs from:
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/train.txt
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/mels
# ...

# %%
# !python /content/drive/MyDrive/Colab\ Notebooks/cloning/vocoder_preprocess.py /content/drive/MyDrive/Colab\ Notebooks/cloning/datasets
# Out:
# Arguments:
#     datasets_root:   /content/drive/MyDrive/Colab Notebooks/cloning/datasets
#     model_dir:       /content/drive/MyDrive/Colab Notebooks/cloning/synthesizer/saved_models/pretrained/
#     hparams:
#     no_trim:         False
#     cpu:             False
#
# Synthesizer using device: cuda
# Trainable Parameters: 30.870M
#
# Loading weights at /content/drive/MyDrive/Colab Notebooks/cloning/synthesizer/saved_models/pretrained/pretrained.pt
# Tacotron weights loaded from step 2000
# Using inputs from:
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/train.txt
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/mels
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/embeds
# Found 1 samples
# ...

# %%
# !python /content/drive/MyDrive/Colab\ Notebooks/cloning/vocoder_train.py my_run  /content/drive/MyDrive/Colab\ Notebooks/cloning/datasets/
# Out:
# Arguments:
#     run_id:          my_run
#     syn_dir:         /content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer
#     voc_dir:         /content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer
#     models_dir:      /content/drive/MyDrive/Colab Notebooks/cloning/vocoder/saved_models
#     ground_truth:    False
#     save_every:      1000
#     backup_every:    25000
#     force_restart:   False
#
# Initializing the model...
# Trainable Parameters: 4.481M
#
# Starting the training of WaveRNN from scratch
#
# Using inputs from:
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/synthesized.txt
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/mels_gta
# 	/content/drive/MyDrive/Colab Notebooks/cloning/datasets/SV2TTS/synthesizer/audio
# Found 1 samples
# +------------+--------+--------------+
# | Batch size |   LR   | Sequence Len |
# +------------+--------+--------------+
# ...

# %%
while True:pass
